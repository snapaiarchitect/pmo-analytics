# %% [markdown]
# # Federal Spend Analytics Dashboard
#
# **Data**: USASpending.gov API
# **Source**: https://api.usaspending.gov/
# **Records**: $4T+ annual obligations, 60M+ transactions
# **Scope**: All federal agencies, FY2008-present
#
# ## Objectives
# 1. Agency-level obligation trends
# 2. Top vendors and contract vehicles
# 3. Geographic distribution of federal spending
# 4. Small business utilization rates

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.load_procurement_data import load_usaspending_contracts

# Load USASpending data
df = load_usaspending_contracts(fy=2024, limit=10000)
print(f'Shape: {df.shape}')
print(f'Columns: {df.columns.tolist()}')
df.head()

# %% [markdown]
# ## 1. Agency Obligation Trends

# %%
# TODO: Time series of top 10 agencies by obligation
# TODO: YoY growth rates and anomaly detection

# %% [markdown]
# ## 2. Vendor Analysis

# %%
# TODO: Top 20 vendors by award amount
# TODO: Vendor concentration (HHI index)

# %% [markdown]
# ## 3. Geographic Heatmap

# %%
# TODO: Obligations by state/ congressional district
# TODO: Per-capita federal spend analysis

# %% [markdown]
# ## Executive Summary
#
# *Placeholder for analysis findings after data load.*
